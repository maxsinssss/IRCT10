# %%
# !pip install networkx matplotlib

import networkx as nx
import matplotlib.pyplot as plt


G = nx.DiGraph()

G.add_edges_from([
    ("A", "B"), ("A", "C"),
    ("B", "C"), ("B", "D"),
    ("C", "A"), ("C", "D"),
    ("D", "B")
])


pagerank_scores = nx.pagerank(G, alpha=0.85)

print("PageRank Scores:")
for node, score in pagerank_scores.items():
    print(f"Page {node}: {score:.4f}")


plt.figure(figsize=(8, 6))
pos = nx.spring_layout(G, seed=42)


node_size = [10000 * pagerank_scores[node] for node in G.nodes()]
nx.draw_networkx_nodes(G, pos, node_size=node_size, node_color='skyblue', alpha=0.9)
nx.draw_networkx_edges(G, pos, arrowstyle='->', arrowsize=20, edge_color='gray')
nx.draw_networkx_labels(G, pos, font_size=14, font_weight='bold')

plt.title("Web Graph with PageRank Scores", fontsize=16)
plt.axis("off")
plt.show()
# Out:
# ...
# PageRank Scores:
# Page A: 0.1396
# Page B: 0.3373
# Page C: 0.2402
# Page D: 0.2829
