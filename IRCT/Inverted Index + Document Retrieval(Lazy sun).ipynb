# %%
document1 = "The quick brown fox jumped over the lazy dog"
document2 = "The lazy dog slept in the sun"

documents = {
    1: document1,
    2: document2
}
import re

def preprocess(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)
    tokens = text.split()
    return tokens


preprocessed_documents = {}
for doc_id, content in documents.items():
    preprocessed_documents[doc_id] = preprocess(content)

print(preprocessed_documents)


inverted_index = {}

for doc_id, tokens in preprocessed_documents.items():
    for token in tokens:
        if token not in inverted_index:
            inverted_index[token] = []
        if doc_id not in inverted_index[token]:
            inverted_index[token].append(doc_id)

print("Inverted Index:")
for term, doc_list in inverted_index.items():
    print(f"{term} → {doc_list}")


term1_docs = set(inverted_index.get('lazy', []))
term2_docs = set(inverted_index.get('sun', []))


result_docs = term1_docs.intersection(term2_docs)

print("\nDocuments containing 'lazy sun':", result_docs)
# Out:
# {1: ['the', 'quick', 'brown', 'fox', 'jumped', 'over', 'the', 'lazy', 'dog'], 2: ['the', 'lazy', 'dog', 'slept', 'in', 'the', 'sun']}
# Inverted Index:
# the → [1, 2]
# quick → [1]
# brown → [1]
# fox → [1]
# jumped → [1]
# over → [1]
# lazy → [1, 2]
# dog → [1, 2]
# slept → [2]
# in → [2]
# sun → [2]
#
# Documents containing 'lazy sun': {2}
