# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity


query = "gold silver truck"
document = "shipment of gold damaged in a gold fire"


vectorizer = CountVectorizer()


documents = [query, document]


vectors = vectorizer.fit_transform(documents)


cos_sim = cosine_similarity(vectors[0], vectors[1])

print("Cosine Similarity between query and document:", cos_sim[0][0])
# Out:
# Cosine Similarity between query and document: 0.3849001794597505
# Note: Cosine similarity ranges from 0 (no similarity) to 1 (identical)
