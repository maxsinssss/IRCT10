# %%
import nltk
from nltk.metrics import edit_distance


word1 = "nature"
word2 = "creature"


distance = edit_distance(word1, word2)

print(f"Edit Distance between '{word1}' and '{word2}': {distance}")
# Out:
# Edit Distance between 'nature' and 'creature': 3
